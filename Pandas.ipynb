# %% [markdown]
# <a href="https://colab.research.google.com/github/rubituladhar21/Machine-Learning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###PANDAS

# %%
import pandas as pd

data = {
    "cars": ["bmw", "honda", "suzuki", "byd"],
    "models": ["2007", "2008", "2015", "2024"],
    "passen": ["4", "6", "6", "5"]
}
data
# Out:
# {'cars': ['bmw', 'honda', 'suzuki', 'byd'],
#  'models': ['2007', '2008', '2015', '2024'],
#  'passen': ['4', '6', '6', '5']}

# %%
#convert the data dictionary to dataframe
df=pd.DataFrame(data)
df
# Out:
#      cars models passen
# 0     bmw   2007      4
# 1   honda   2008      6
# 2  suzuki   2015      6
# 3     byd   2024      5

# %%
df.to_csv("cars_data.csv")

# %%
#create datadictionary to dataframe
calories      duration
420             50
500             60
390             45

# %%
import pandas as pd
data= {
    "calories": ["420", "500", "390"],
    "duration": ["50", "60", "45"]
}
data
# Out:
# {'calories': ['420', '500', '390'], 'duration': ['50', '60', '45']}

# %%
df=pd.DataFrame(data)
df
# Out:
#   calories duration
# 0      420       50
# 1      500       60
# 2      390       45
