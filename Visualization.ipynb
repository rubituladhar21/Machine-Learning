# %% [markdown]
# <a href="https://colab.research.google.com/github/rubituladhar21/Machine-Learning/blob/main/Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Basics of Matplotlib
#Line plot
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y, label="sine wave")
plt.title("Line plot example")
plt.xlabel("-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.show()

# %%
# Bar chart
categories = ['A', 'B', 'C','D','E']
values = [10, 20, 30, 40, 50]
color = ['red', 'green', 'blue', 'gray', 'brown']
plt.bar(categories, values, color = color)
plt.title("Bar Chart Example")
plt.xlabel("categories")
plt.ylabel("values")
plt.show()

# %% [markdown]
# ###Visualization with seaborn

# %%
import seaborn as sns

# %%
# Histogram and KDE plot:
data = np.random.randn(1000)
sns.histplot(data,kde=True, color='green')
plt.title("Histogram with KDE")
plt.show()

# %%
# Heatmap
matrix = np.random.rand(5, 5)
matrix
# Out:
# array([[0.80687167, 0.51340084, 0.30081332, 0.84837926, 0.4423073 ],
#        [0.61257632, 0.7591265 , 0.61540667, 0.91432894, 0.88758025],
#        [0.23646148, 0.94832494, 0.2828129 , 0.22294647, 0.32974383],
#        [0.1955349 , 0.57258105, 0.99878809, 0.42602677, 0.62428241],
#        [0.73533581, 0.4194401 , 0.0663632 , 0.38334853, 0.71837483]])

# %%
sns.heatmap(matrix, annot=True, cmap="hsv")
plt.title("Heatmap Example")
plt.show()

# %%
# pairplot example
sns.set_style("whitegrid")
df = sns.load_dataset("iris")
sns.pairplot(df, hue="species", markers=["o", "s", "D"])
plt.show()
